# %%
from apin.core.ai.kagent import generate_helm_template

# %%
response = generate_helm_template("""
Generate a HELM chart for a deployment called apin-kagent. 
Use the port 8008 for the service
For the deployment allow the following to be configured by values.yaml. 
- replicas
- the docker image to use
- the memory resources and cpu resources (set low defaults but allow the configuration via values.yaml)
Add an extra pod to the helm module called apin-scheduler. Specifcally for the pod apply the following logic:
- the entry point for the apin-scheduler pod should be ["poetry", "run", "apin ", "scheduler", "start"] 
- the apin-scheduler pod's resources should be fixed to low defaults 
- its image should be the same image  as the deployment so it can point to the same image in the values.yaml
    """)
# Out:
# 2023-10-23 11:20:20.133 | DEBUG    | apin.core.ai.kagent:file_gen:73 - Generating. Please wait a moment...
# 2023-10-23 11:21:28.590 | INFO     | apin.core.ai.kagent:file_gen:77 - ---
# ```json
# {
#   "files" : ["Chart.yaml", "values.yaml", "templates/service.yaml", "templates/deployment.yaml", "templates/scheduler.yaml", "kustomization.yaml"]
# }
# ```
#
# ---
# ```yaml
# # Chart.yaml
# apiVersion: v2
# name: apin-kagent
# version: 0.1.0
# description: A simple Helm chart for Kubernetes
# type: application
# ```
# ---
# ```yaml
# # values.yaml
# replicaCount: 1
# image:
#   repository: nginx
#   tag: stable
#   pullPolicy: IfNotPresent
# resources:
#   requests:
#     cpu: 100m
#     memory: 128Mi
#   limits:
#     cpu: 200m
#     memory: 256Mi
# service:
#   type: ClusterIP
#   port: 8008
# ```
# ---
# ```yaml
# # templates/service.yaml
# apiVersion: v1
# kind: Service
# metadata:
#   name: {{ include "apin-kagent.fullname" . }}
# spec:
#   type: {{ .Values.service.type }}
#   ports:
#     - port: {{ .Values.service.port }}
#       targetPort: http
#       protocol: TCP
#       name: http
#   selector:
#     app.kubernetes.io/name: {{ include "apin-kagent.name" . }}
#     app.kubernetes.io/instance: {{ .Release.Name }}
# ```
# ---
# ```yaml
# # templates/deployment.yaml
# apiVersion: apps/v1
# kind: Deployment
# metadata:
#   name: {{ include "apin-kagent.fullname" . }}
# spec:
#   replicas: {{ .Values.replicaCount }}
#   selector:
#     matchLabels:
#       app.kubernetes.io/name: {{ include "apin-kagent.name" . }}
#       app.kubernetes.io/instance: {{ .Release.Name }}
#   template:
#     metadata:
#       labels:
#         app.kubernetes.io/name: {{ include "apin-kagent.name" . }}
#         app.kubernetes.io/instance: {{ .Release.Name }}
#     spec:
#       containers:
#         - name: {{ .Chart.Name }}
#           image: "{{ .Values.image.repository }}:{{ .Values.image.tag }}"
#           imagePullPolicy: {{ .Values.image.pullPolicy }}
#           resources:
#             {{- toYaml .Values.resources | nindent 12 }}
# ```
# ---
# ```yaml
# # templates/scheduler.yaml
# apiVersion: v1
# kind: Pod
# metadata:
#   name: apin-scheduler
# spec:
#   containers:
#   - name: apin-scheduler
#     image: "{{ .Values.image.repository }}:{{ .Values.image.tag }}"
#     command: ["poetry", "run", "apin", "scheduler", "start"]
#     resources:
#       requests:
#         cpu: "100m"
#         memory: "128Mi"
#       limits:
#         cpu: "200m"
#         memory: "256Mi"
# ```
# ---
# ```yaml
# # kustomization.yaml
# apiVersion: kustomize.config.k8s.io/v1beta1
# kind: Kustomization
# images:
# - name: nginx
#   newName: my-registry/foo/bar
#   newTag: v2
# bases:
# - ./helmchart/apin-kagent
# ```
#
# 2023-10-23 11:21:28.596 | INFO     | apin.core.ai.kagent:file_gen:88 - Writing /Users/sirsh/code/mr_saoirse/app.pinnings/stack/test/Chart.yaml
# 2023-10-23 11:21:28.599 | INFO     | apin.core.ai.kagent:file_gen:88 - Writing /Users/sirsh/code/mr_saoirse/app.pinnings/stack/test/values.yaml
# 2023-10-23 11:21:28.601 | INFO     | apin.core.ai.kagent:file_gen:88 - Writing /Users/sirsh/code/mr_saoirse/app.pinnings/stack/test/templates/service.yaml
# 2023-10-23 11:21:28.602 | INFO     | apin.core.ai.kagent:file_gen:88 - Writing /Users/sirsh/code/mr_saoirse/app.pinnings/stack/test/templates/deployment.yaml
# 2023-10-23 11:21:28.604 | INFO     | apin.core.ai.kagent:file_gen:88 - Writing /Users/sirsh/code/mr_saoirse/app.pinnings/stack/test/templates/scheduler.yaml
# 2023-10-23 11:21:28.605 | INFO     | apin.core.ai.kagent:file_gen:88 - Writing /Users/sirsh/code/mr_saoirse/app.pinnings/stack/test/kustomization.yaml
